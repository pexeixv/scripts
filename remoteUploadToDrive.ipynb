# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/Shareddrives/Storage1')

# %%
url = input('Enter URL: ')
# !wget -c $url --no-check-certificate
# Out:
# Enter URL: https://s1.sleazyvids.net/mp4/videos/P_vYU3Liv7kXxqXXmdXSLQ/1632071748/Evil.Come.Evil.Go.1972.mp4
# --2021-09-19 07:08:15--  https://s1.sleazyvids.net/mp4/videos/P_vYU3Liv7kXxqXXmdXSLQ/1632071748/Evil.Come.Evil.Go.1972.mp4
# Resolving s1.sleazyvids.net (s1.sleazyvids.net)... 95.216.23.56
# Connecting to s1.sleazyvids.net (s1.sleazyvids.net)|95.216.23.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 724474871 (691M) [video/mp4]
# Saving to: ‘Evil.Come.Evil.Go.1972.mp4’
#
# Evil.Come.Evil.Go.1 100%[===================>] 690.91M   757KB/s    in 15m 43s
#
# 2021-09-19 07:23:58 (751 KB/s) - ‘Evil.Come.Evil.Go.1972.mp4’ saved [724474871/724474871]

# %%
# !wget -c 'https://gavinpereira.in/img/preview.jpg' --no-check-certificate
# Out:
# --2021-09-19 07:25:45--  https://gavinpereira.in/img/preview.jpg
# Resolving gavinpereira.in (gavinpereira.in)... 184.72.37.151, 184.72.19.87
# Connecting to gavinpereira.in (gavinpereira.in)|184.72.37.151|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 256579 (251K) [image/jpeg]
# Saving to: ‘preview.jpg’
#
# preview.jpg         100%[===================>] 250.57K   968KB/s    in 0.3s
#
# 2021-09-19 07:25:45 (968 KB/s) - ‘preview.jpg’ saved [256579/256579]
